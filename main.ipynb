# %%
#create a car game using tkinter
from tkinter import *
import random
import time
import tkinter.messagebox
#creating a window
root = Tk()
root.geometry("1600x800+0+0")
root.title("Car Game")
root.configure(background='black')
#creating a canvas
canvas = Canvas(root, width=300, height=300)
canvas.pack()
#creating a frame
frame = Frame(root)
frame.pack()
#creating a button
button = Button(frame, text="QUIT", fg="red", command=quit)
button.pack(side=LEFT)
# #creating a button
# hbutton = Button(frame, text="Hello", command=hello)
# hbutton.pack(side=LEFT)
#define heelo function
def hello():
    print("hello")
#creating a label
label = Label(root, text="Hello World")
label.pack(side=TOP)
#creating a menu
menubar = Menu(root)
filemenu = Menu(menubar, tearoff=0)
filemenu.add_command(label="New")
filemenu.add_command(label="Open")
filemenu.add_command(label="Save")
filemenu.add_command(label="Save as...")
filemenu.add_command(label="Close")

filemenu.add_separator()
filemenu.add_command(label="Exit", command=root.quit)
menubar.add_cascade(label="File", menu=filemenu)
editmenu = Menu(menubar, tearoff=0)
editmenu.add_command(label="Undo")
editmenu.add_separator()
editmenu.add_command(label="Cut")
editmenu.add_command(label="Copy")
editmenu.add_command(label="Paste")
editmenu.add_command(label="Delete")
editmenu.add_command(label="Select All")
menubar.add_cascade(label="Edit", menu=editmenu)
helpmenu = Menu(menubar, tearoff=0)
helpmenu.add_command(label="Help Index")
helpmenu.add_command(label="About...")
menubar.add_cascade(label="Help", menu=helpmenu)
root.config(menu=menubar)



#creating a car
class Car:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        random.shuffle(starts)
        self.x = starts[0]
        self.y = 0
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 1
        if pos[3] >= self.canvas_height:
            self.y = -1
        if pos[0] <= 0:
            self.x = 1
        if pos[2] >= self.canvas_width:
            self.x = -1
#creating a ball
class Ball:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        random.shuffle(starts)
        self.x = starts[0]
        self.y = -3
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 3
        if pos[3] >= self.canvas_height:
            self.y = -3
        if pos[0] <= 0:
            self.x = 3
        if pos[2] >= self.canvas_width:
            self.x = -3

#creating a paddle
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0
    def turn_left(self, evt):
        self.x = -2
    def turn_right(self, evt):
        self.x = 2

#creating a score
score = 0
#creating a lives
lives = 3
#creating a paddle
paddle = Paddle(canvas, 'blue')
#creating a ball
ball = Ball(canvas, 'red')
#creating a car
car = Car(canvas, 'green')
#creating a game over
game_over_text = canvas.create_text(250, 120, text='GAME OVER', state='hidden')
#creating a score
score_text = canvas.create_text(450, 120, text='Score: ' + str(score), state='hidden')
#creating a lives
lives_text = canvas.create_text(450, 140, text='Lives: ' + str(lives), state='hidden')
#creating a game over
game_over_text = canvas.create_text(250, 120, text='GAME OVER', state='hidden')

#creating a game loop
while 1:
    if lives > 0:
        ball.draw()
        paddle.draw()
        car.draw()
        #creating a collision
        pos = canvas.coords(ball.id)
        pos2 = canvas.coords(paddle.id)
        pos3 = canvas.coords(car.id)
        if pos[2] >= pos2[0] and pos[0] <= pos2[2]:
            if pos[3] >= pos2[1] and pos[3] <= pos2[3]:
                ball.y = -3
                score += 1
                canvas.itemconfig(score_text, text='Score: ' + str(score))
        if pos[2] >= pos3[0] and pos[0] <= pos3[2]:
            if pos[3] >= pos3[1] and pos[3] <= pos3[3]:
                ball.y = -3
                lives -= 1
                canvas.itemconfig(lives_text, text='Lives: ' + str(lives))
    else:
        canvas.itemconfig(game_over_text, state='normal')
    root.update_idletasks()
    root.update()
    time.sleep(0.01)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3716/3040980279.py in <module>
#     165                 canvas.itemconfig(lives_text, text='Lives: ' + str(lives))
#     166     else:
# --> 167         canvas.itemconfig(game_over_text, state='normal')
#     168     root.update_idletasks()
#     169     root.update()
#
# d:\Users\YASWANTH\anaconda3\envs\auto\lib\tkinter\__init__.py in itemconfigure(self, tagOrId, cnf, **kw)
#    2901         the allowed keyword arguments call the method without arguments.
#    2902         """
# -> 2903         return self._configure(('itemconfigure', tagOrId), cnf, kw)
#    2904
#    2905     itemconfig = itemconfigure
#
# d:\Users\YASWANTH\anaconda3\envs\auto\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1634         if isinstance(cnf, str):
# ...
